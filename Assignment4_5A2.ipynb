# %% [markdown]
# <a href="https://colab.research.google.com/github/Srilatha23/AI/blob/main/Assignment4_5A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Import required libraries

# %%
import numpy as np
import math as mt
import random
import pandas as pd

# %% [markdown]
# Import Data

# %%
data = pd.read_csv('/content/drive/MyDrive/AI4.csv')
data.head()
# Out:
#      X    Y
# 0  7.6  157
# 1  7.1  174
# 2  8.2  175
# 3  7.5  188
# 4  7.4  171

# %% [markdown]
# Outliers Treatment

# %%
outliers = []
def detect_outliers_zscore(data):
    thres = 3
    mean = np.mean(data)
    std = np.std(data)
    for i in data:
        z_score = (i-mean)/std
        if (np.abs(z_score) > thres):
            outliers.append(i)
    return outliers

# %%
sample_outliers_X = detect_outliers_zscore(data['X'])
sample_outliers_Y = detect_outliers_zscore(data['Y'])
print("Outliers in X column from Z-scores method: ", sample_outliers_X)
print("Outliers in Y column from Z-scores method: ", sample_outliers_Y)
# Out:
# Outliers in X column from Z-scores method:  []
# Outliers in Y column from Z-scores method:  []

# %% [markdown]
# Missing Values Treatment

# %%
print(data.isnull().sum())
# Out:
# X    0
# Y    0
# dtype: int64

# %%
m1=data['X'].mean()
m2=data['Y'].mean()
data['X'].fillna(value=m1, inplace=True)
data['Y'].fillna(value=m2, inplace=True)
data
# Out:
#       X    Y
# 0   7.6  157
# 1   7.1  174
# 2   8.2  175
# 3   7.5  188
# 4   7.4  171
# 5   7.8  143
# 6   7.3  217
# 7   8.0  190
# 8   7.1  142
# 9   7.5  190
# 10  8.1  215
# 11  7.0  199
# 12  7.3  262
# 13  7.8  105
# 14  7.3  121
# 15  8.0   81
# 16  8.5   82
# 17  7.1  210
# 18  8.2  202
# 19  7.9  155
# 20  7.6  157
# 21  8.8  147
# 22  7.2  133
# 23  7.9   53
# 24  8.1   56
# 25  7.7  113
# 26  8.4   35
# 27  7.4  125
# 28  7.3   76
# 29  8.5   48
# 30  7.8  147
# 31  6.7  117
# 32  7.1  182
# 33  7.3   87

# %% [markdown]
# Data Split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data.X, data.Y, test_size = 0.20, random_state = 10)

# %% [markdown]
# Initialization

# %%
m=random.uniform(-10,10)
c=random.uniform(-10,10)
eta=0.01
max_iter=10000

# %% [markdown]
# Gradient Calculation

# %%
def gradient(m,c,x,y):
  m_deriv=-1*(y-m*x-c)*x
  c_deriv=-1*(y-m*x-c)
  return m_deriv,c_deriv

# %% [markdown]
# Training Using Stochastic Gradient Descent Optimizer

# %%
for iter in range(max_iter):
  for sample in range(x_train.shape[0]):
    del_m,del_c=gradient(m, c, x_train.iloc[sample], y_train.iloc[sample])
    m=m-eta*del_m
    c=c-eta*del_c
print('model parameter m and c',m,c)
# Out:
# model parameter m and c -32.62908028410184 405.26993673025686

# %% [markdown]
# Model Prediction on Training Data

# %%
y_pred_train = []
for i in x_train:
  y_p_tr = (m * i) + c
  y_pred_train.append(y_p_tr)
y_pred_train = np.array(y_pred_train)

# %% [markdown]
# Model Prediction on Testing Data

# %%
y_pred_test = []
for i in x_test:
  y_p_te = (m * i) + c
  y_pred_test.append(y_p_te)
y_pred_test = np.array(y_pred_test)

# %% [markdown]
# Error Metrics Calculation

# %%
import math
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import mean_absolute_error

#Training Accuracies
rmse = math.sqrt(mean_squared_error(y_train, y_pred_train)) 
print('Root mean square error', rmse) 
mse = (mean_squared_error(y_train, y_pred_train)) 
print('Mean square error', mse) 
mae=mean_absolute_error(y_train, y_pred_train)
print('Mean absolute error', mae)
# Out:
# Root mean square error 51.90664428778604
# Mean square error 2694.2997212187506
# Mean absolute error 42.490300162994494

# %%
#Testing Accuracies
mse = math.sqrt(mean_squared_error(y_test, y_pred_test)) 
print('Root mean square error', mse) 
mse = (mean_squared_error(y_test, y_pred_test)) 
print('Mean square error', mse) 
mae=mean_absolute_error(y_test, y_pred_test)
print('Mean absolute error', mae)
# Out:
# Root mean square error 58.10481259639052
# Mean square error 3376.1692468616625
# Mean absolute error 49.28937336728114

# %% [markdown]
# ![ai aasgn4-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![ai aasgn4-2.jpg](data:image/jpeg;base64,...)
